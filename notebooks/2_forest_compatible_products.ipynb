# %% [markdown]
# ## Importing the libraries

# %%
from google.colab import drive
drive.mount ("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import  pandas as pd
import  seaborn as sns
import  scipy.stats as stats
import  matplotlib.pyplot as plt

# %% [markdown]
# # Grouping forest-compatible products by HS4

# %%
data = pd.read_csv('/content/drive/MyDrive/Data Competitions/BCG Gamma 2022/Dados - GAMMA Challenge 2022/Dados Extras/produtos_compativeis_com_a_floresta.csv', delimiter=';', dtype = {'hs6': "str"})
data.set_index('id', inplace=True)
data
# Out:
#        hs6                                        description  \
# id
# 1   090411  Pimenta (do gênero piper), seca, não  triturad...
# 2   030389        Outros peixes, exceto fígados, ovas e sêmen
# 3   151110                           Óleos de dendê, em bruto
# 4   200989  Suco (sumo) de qualquer outra fruta ou produto...
# 5   030572    Cabeças, caudas e bexigas natatórias, de peixes
# ..     ...                                                ...
# 60  070490  Couves, repolhos e produtos comestíveis semelh...
# 61  080132        Castanha de caju, fresca ou seca, sem casca
# 62  030499  Carnes de outros peixes, exceto filés, mesmo p...
# 63  030469        Filé de peixe cabeça-de-serpente, congelado
# 64  200820                 Abacaxis preparados ou conservados
#
#    brazilian_exports     world_exports brazilian_market_share
# id
# 1     107.929.737,00  1.488.534.670,00                  7,25%
# 2      33.123.476,00  4.053.050.315,00                  0,82%
# 3      27.492.944,00  8.699.395.419,00                  0,32%
# 4      24.424.377,00  2.551.701.372,00                  0,96%
# 5      19.654.863,00    427.154.174,00                  4,60%
# ..               ...               ...                    ...
# 60         15.681,00  1.862.922.540,00                  0,00%
# 61         13.796,00  4.925.260.480,00                  0,00%
# 62         12.253,00  2.098.727.354,00                  0,00%
# 63         10.366,00     52.728.252,00                  0,02%
# 64         10.152,00  1.094.354.823,00                  0,00%
#
# [64 rows x 5 columns]

# %%
# Products to be removed: non edible and related to fishing
non_comestible_ids = [9, 20, 21, 22, 23, 25, 41, 45, 50, 54]
fish_product_ids = [2, 5, 9, 11, 18, 31, 35, 51, 58, 62, 63, 13, 17, 37, 38, 46]

removable_ids = non_comestible_ids + fish_product_ids
data.drop(index=removable_ids, inplace=True)

# %%
data['hs4'] = data.apply(lambda row : row['hs6'][:4], axis=1)

# %%
# Group by HS4, concatenating descriptions
hs4_data = data.groupby(['hs4'],as_index=False).agg(lambda x : ' / '.join(x))[['hs4', 'description']]

# %% [markdown]
# # Value by product

# %%
# Source: WITS World Bank
# Query: Brazilian exports in 2022
value_by_product = pd.read_csv('/content/drive/MyDrive/Data Competitions/BCG Gamma 2022/Dados - GAMMA Challenge 2022/Dados Extras/valor_por_produto.csv', dtype = {'ProductCode': "str"})

# %%
# Select by HS4
value_by_product['hs4'] = value_by_product.apply(lambda row : row['ProductCode'][:4], axis=1)

# %%
# Group by HS4 summing values
value_by_product_hs4 = value_by_product.groupby(['hs4'],as_index=False).sum()

# %%
# Produces value by kg
value_by_product_hs4['per_kg'] = value_by_product_hs4['TradeValue in 1000 USD'] * 1000 / valor_por_produto_hs4['NetWeight in KGM']

# %%
value_by_product_hs4[['hs4', 'per_kg']]
# Out:
#      hs4     per_kg
# 0   0302   6.117393
# 1   0303   4.301257
# 2   0304   8.591435
# 3   0305  31.447248
# 4   0306  35.299053
# 5   0307   7.655053
# 6   0409   3.461353
# 7   0704   0.442514
# 8   0712   1.484810
# 9   0801   5.555858
# 10  0804   0.934449
# 11  0811   2.257296
# 12  0813  22.344586
# 13  0901   2.542738
# 14  0904   3.326999
# 15  0907   5.688014
# 16  0910   9.269575
# 17  1211  12.727154
# 18  1212   0.353227
# 19  1301   8.411294
# 20  1302   5.290811
# 21  1511   1.396096
# 22  1513   1.904338
# 23  1801   3.964849
# 24  1806   3.916125
# 25  2006   0.952838
# 26  2008   2.173102
# 27  2009   1.593005
# 28  3203   6.280618

# %%
product_value_map = dict(zip(value_by_product_hs4['hs4'], value_by_product_hs4['per_kg']))

# %%
hs4_data['hs4'].map(product_value_map)
# Out:
# 0      3.461353
# 1      0.442514
# 2      1.484810
# 3      5.555858
# 4      0.934449
# 5      2.257296
# 6     22.344586
# 7      2.542738
# 8      3.326999
# 9      5.688014
# 10     9.269575
# 11    12.727154
# 12     0.353227
# 13     8.411294
# 14     5.290811
# 15     1.396096
# 16     1.904338
# 17     3.964849
# 18     3.916125
# 19     0.952838
# 20     2.173102
# 21     1.593005
# 22     6.280618
# Name: hs4, dtype: float64

# %%
hs4_data['value_per_kg'] = hs4_data['hs4'].map(product_value_map)

# %%
hs4_data
# Out:
#      hs4                                        description  value_per_kg
# 0   0409                                        Mel natural      3.461353
# 1   0704  Couves, repolhos e produtos comestíveis semelh...      0.442514
# 2   0712  Cebolas secas, inclusive em pedaços ou fatias,...      1.484810
# 3   0801  Castanha-do-pará, fresca ou seca, sem casca / ...      5.555858
# 4   0804  Goiabas, mangas e mangostões, frescos ou secos...      0.934449
# 5   0811  Outras frutas congeladas, não cozidas ou cozid...      2.257296
# 6   0813                        Pêras e outras frutas secas     22.344586
# 7   0901                 Café não torrado, não descafeinado      2.542738
# 8   0904  Pimenta (do gênero piper), seca, não  triturad...      3.326999
# 9   0907  Cravo-da-índia (frutos, flores e pedúnculo) nã...      5.688014
# 10  0910                                 Outras especiarias      9.269575
# 11  1211  Raízes de ginseng, frescas ou secas, mesmo cor...     12.727154
# 12  1212  Outras algas, frescas, refrigeradas, congelada...      0.353227
# 13  1301                                       Goma-arábica      8.411294
# 14  1302  Sucos e extratos de outros vegetais (mamão sec...      5.290811
# 15  1511  Óleos de dendê, em bruto / Outros óleos de den...      1.396096
# 16  1513  Óleo de palmiste ou de babaçu, em bruto / Outr...      1.904338
# 17  1801      Cacau inteiro ou partido, em bruto ou torrado      3.964849
# 18  1806  Chocolate e outras preparações alimentícias co...      3.916125
# 19  2006  Produtos hortícolas, frutas e cascas, conserva...      0.952838
# 20  2008  Outras frutas e partes de plantas, preparadas ...      2.173102
# 21  2009  Suco (sumo) de qualquer outra fruta ou produto...      1.593005
# 22  3203  Matérias corantes de origem vegetal ou animal ...      6.280618

# %%
hs4_data.to_csv('/content/drive/MyDrive/Data Competitions/BCG Gamma 2022/Dados - GAMMA Challenge 2022/Dados Extras/produtos_hs4_filtrados_com_preco.csv', index=False)
